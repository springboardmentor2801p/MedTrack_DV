# %%
import pandas as pd
import numpy as np

# %%
path = "../data/processed/hospital_raw_data.csv"

df = pd.read_csv(path)

print(df.shape)
df.head()
# Out:
# (45000, 58)
#    admission_id admission_date discharge_date admission_type admission_status  \
# 0         10703     2020-01-01     2020-01-04      Emergency       Discharged
# 1          1044     2020-01-01     2020-01-06       Elective       Discharged
# 2          9446     2020-01-01     2020-01-02      Emergency       Discharged
# 3         33351     2020-01-01     2020-01-02      Emergency       Discharged
# 4         21625     2020-01-01     2020-01-06       Elective       Discharged
#
#    patient_id  department_id  ward_id  bed_id  disease_id  ... admission_year  \
# 0       24223              4       19     276          17  ...           2020
# 1       19446              5       23     349           5  ...           2020
# 2       17151              5       21     301           5  ...           2020
# 3        9933              4       17     258           1  ...           2020
# 4        8146              4       18     270           8  ...           2020
#
# ...

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# patient_insurance_id     17889
# policy_start_date        17889
# policy_end_date          17889
# insurance_provider_id    17889
# provider_type            17889
# contact_details          17889
# dtype: int64

# %%
print("Before:", df.shape)

df = df.drop_duplicates()

print("After:", df.shape)
# Out:
# Before: (45000, 58)
# After: (45000, 58)

# %%
patient_cols = [
    "gender",
    "date_of_birth",
    "blood_group",
    "city",
    "contact_number"
]

for col in patient_cols:
    df[col] = df[col].fillna("Unknown")

# %%
output = "../data/cleaned/hospital_cleaned.csv"

df.to_csv(output,index=False)

print("Clean file created")
# Out:
# Clean file created

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_percent[
    missing_percent > 0
]
# Out:
# patient_insurance_id     39.753333
# policy_start_date        39.753333
# policy_end_date          39.753333
# insurance_provider_id    39.753333
# provider_type            39.753333
# contact_details          39.753333
# dtype: float64

# %%
insurance_cols = [
    "provider_type",
    "contact_details"
]

for col in insurance_cols:
    df[col] = df[col].fillna("Unknown")

# %%
df[insurance_cols].isnull().sum()
# Out:
# provider_type      0
# contact_details    0
# dtype: int64

# %%
print("Before:", df.shape)

df = df.drop_duplicates()

print("After:", df.shape)
# Out:
# Before: (45000, 58)
# After: (45000, 58)

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# insurance_provider_id    17889
# patient_insurance_id     17889
# policy_end_date          17889
# policy_start_date        17889
# admission_status             0
# patient_id                   0
# discharge_date               0
# admission_type               0
# admission_id                 0
# admission_date               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(71556)

# %%
df["department_name"].value_counts()
# Out:
# department_name
# Surgery              10126
# Emergency             8777
# Pediatrics            8438
# Internal Medicine     7695
# Orthopedics           5924
# ICU                   4040
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(71556)

# %%
df.columns.tolist()
# Out:
# ['admission_id',
#  'admission_date',
#  'discharge_date',
#  'admission_type',
#  'admission_status',
#  'patient_id',
#  'department_id',
#  'ward_id',
#  'bed_id',
#  'disease_id',
#  'gender',
#  'date_of_birth',
#  'blood_group',
#  'city',
#  'contact_number',
#  'department_name',
#  'department_type',
#  'floor_number',
#  'status',
#  'ward_name',
#  'ward_type',
#  'total_beds',
#  'bed_number',
#  'bed_status',
#  'disease_name',
#  'disease_category',
#  'bill_id',
#  'bill_date',
#  'total_amount',
#  'insurance_covered_amount',
#  'patient_payable_amount',
#  'payment_status',
#  'payment_mode',
#  'patient_insurance_id',
#  'policy_number',
#  'coverage_percentage',
#  'policy_start_date',
#  'policy_end_date',
#  'insurance_provider_id',
#  'provider_name',
#  'provider_type',
#  'contact_details',
#  'coverage_limit',
#  'length_of_stay',
#  'patient_age',
#  'age_group',
#  'insurance_status',
#  'revenue_category',
#  'admission_year',
#  'admission_month',
# ...

# %%
categorical_cols = [
    "admission_type",
    "admission_status",
    "department_name",
    "department_type",
    "bed_status",
    "stay_category",
    "disease_load_category",
    "bed_occupancy_flag"
]

for col in categorical_cols:
    print("\n", col)
    print(df[col].unique())
# Out:
#  admission_type
# <StringArray>
# ['Emergency', 'Elective']
# Length: 2, dtype: str
#
#  admission_status
# <StringArray>
# ['Discharged']
# Length: 1, dtype: str
#
#  department_name
# <StringArray>
# ['Pediatrics', 'Orthopedics', 'Emergency', 'Internal Medicine', 'Surgery',
#  'ICU']
# Length: 6, dtype: str
#
#  department_type
# <StringArray>
# ['Clinical']
# Length: 1, dtype: str
#
#  bed_status
# <StringArray>
# ['Available']
# Length: 1, dtype: str
#
#  stay_category
# <StringArray>
# ['Short Stay', 'Medium Stay', 'Long Stay']
# Length: 3, dtype: str
#
#  disease_load_category
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\MedTrack_DV\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# ...

# %%
df["bed_status"].value_counts()
# Out:
# bed_status
# Available    45000
# Name: count, dtype: int64

# %%
numeric_cols = [
    "total_beds",
    "department_revenue",
    "disease_load"
]

df[numeric_cols].describe()
# Out:
#          total_beds  department_revenue  disease_load
# count  45000.000000        45000.000000  45000.000000
# mean      16.194222        37427.691311   2250.538356
# std        3.846462        20898.321091     34.661347
# min       10.000000         5001.000000   2184.000000
# 25%       15.000000        21231.000000   2239.000000
# 50%       15.000000        34623.500000   2253.000000
# 75%       20.000000        48039.250000   2282.000000
# max       20.000000        89990.000000   2300.000000

# %%
df.to_csv("hospital_cleaned.csv", index=False)

# %%
df.to_csv("hospital_cleaned.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 59 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   admission_id              45000 non-null  int64
#  1   admission_date            45000 non-null  str
#  2   discharge_date            45000 non-null  str
#  3   admission_type            45000 non-null  str
#  4   admission_status          45000 non-null  str
#  5   patient_id                45000 non-null  int64
#  6   department_id             45000 non-null  int64
#  7   ward_id                   45000 non-null  int64
#  8   bed_id                    45000 non-null  int64
#  9   disease_id                45000 non-null  int64
#  10  gender                    45000 non-null  str
#  11  date_of_birth             45000 non-null  str
#  12  blood_group               45000 non-null  str
#  13  city                      45000 non-null  str
# ...

# %%
df.to_csv("hospital_cleaned.csv", index=False)

# %%
import os

print(os.path.exists("hospital_cleaned.csv"))
# Out:
# True

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Missing Values:", df.isnull().sum().sum())
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Rows: 45000
# Columns: 59
# Missing Values: 0
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()

# %%
print("Rows after removing duplicates:", df.shape[0])
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Rows after removing duplicates: 45000
# Duplicate Rows: 0

# %%
df.to_csv("hospital_cleaned.csv", index=False)

# %%
import os

print(os.path.exists("hospital_cleaned.csv"))
# Out:
# True

# %%
import pandas as pd
import os

BASE_DIR = r"D:\MedTrack_DV"

RAW_PATH = os.path.join(
    BASE_DIR,
    "data",
    "processed",
    "hospital_raw_data.csv"
)

print(RAW_PATH)

df = pd.read_csv(RAW_PATH)

df.head()
# Out:
# D:\MedTrack_DV\data\processed\hospital_raw_data.csv
#    admission_id admission_date discharge_date admission_type admission_status  \
# 0         10703     2020-01-01     2020-01-04      Emergency       Discharged
# 1          1044     2020-01-01     2020-01-06       Elective       Discharged
# 2          9446     2020-01-01     2020-01-02      Emergency       Discharged
# 3         33351     2020-01-01     2020-01-02      Emergency       Discharged
# 4         21625     2020-01-01     2020-01-06       Elective       Discharged
#
#    patient_id  department_id  ward_id  bed_id  disease_id  ... admission_year  \
# 0       24223              4       19     276          17  ...           2020
# 1       19446              5       23     349           5  ...           2020
# 2       17151              5       21     301           5  ...           2020
# 3        9933              4       17     258           1  ...           2020
# ...

# %%
os.listdir(r"D:\MedTrack_DV\data\processed")
# Out:
# ['hospital_raw_data.csv']

# %%
df.shape
# Out:
# (45000, 58)

# %%
df = pd.read_csv(RAW_PATH)

df.head()
# Out:
#    admission_id admission_date discharge_date admission_type admission_status  \
# 0         10703     2020-01-01     2020-01-04      Emergency       Discharged
# 1          1044     2020-01-01     2020-01-06       Elective       Discharged
# 2          9446     2020-01-01     2020-01-02      Emergency       Discharged
# 3         33351     2020-01-01     2020-01-02      Emergency       Discharged
# 4         21625     2020-01-01     2020-01-06       Elective       Discharged
#
#    patient_id  department_id  ward_id  bed_id  disease_id  ... admission_year  \
# 0       24223              4       19     276          17  ...           2020
# 1       19446              5       23     349           5  ...           2020
# 2       17151              5       21     301           5  ...           2020
# 3        9933              4       17     258           1  ...           2020
# 4        8146              4       18     270           8  ...           2020
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 58 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   admission_id              45000 non-null  int64
#  1   admission_date            45000 non-null  str
#  2   discharge_date            45000 non-null  str
#  3   admission_type            45000 non-null  str
#  4   admission_status          45000 non-null  str
#  5   patient_id                45000 non-null  int64
#  6   department_id             45000 non-null  int64
#  7   ward_id                   45000 non-null  int64
#  8   bed_id                    45000 non-null  int64
#  9   disease_id                45000 non-null  int64
#  10  gender                    45000 non-null  str
#  11  date_of_birth             45000 non-null  str
#  12  blood_group               45000 non-null  str
#  13  city                      45000 non-null  str
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# provider_type               17889
# patient_insurance_id        17889
# contact_details             17889
# policy_start_date           17889
# policy_end_date             17889
# insurance_provider_id       17889
# discharge_date                  0
# admission_type                  0
# admission_id                    0
# admission_date                  0
# gender                          0
# date_of_birth                   0
# blood_group                     0
# city                            0
# contact_number                  0
# department_name                 0
# department_type                 0
# floor_number                    0
# status                          0
# ward_name                       0
# admission_status                0
# patient_id                      0
# department_id                   0
# ward_id                         0
# bed_id                          0
# disease_id                      0
# disease_category                0
# ...

# %%
drop_cols = [
    "provider_type",
    "patient_insurance_id",
    "contact_details",
    "policy_start_date",
    "policy_end_date",
    "insurance_provider_id"
]

df = df.drop(
    columns=[col for col in drop_cols if col in df.columns]
)

print(df.shape)
# Out:
# (45000, 52)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# admission_id                0
# admission_date              0
# discharge_date              0
# admission_type              0
# admission_status            0
# patient_id                  0
# department_id               0
# ward_id                     0
# bed_id                      0
# disease_id                  0
# gender                      0
# date_of_birth               0
# blood_group                 0
# city                        0
# contact_number              0
# department_name             0
# department_type             0
# floor_number                0
# status                      0
# ward_name                   0
# ward_type                   0
# total_beds                  0
# bed_number                  0
# bed_status                  0
# disease_name                0
# disease_category            0
# bill_id                     0
# bill_date                   0
# total_amount                0
# insurance_covered_amount    0
# patient_payable_amount      0
# ...

# %%
print("Before duplicates:", df.shape)

df = df.drop_duplicates()

print("After duplicates:", df.shape)

print("Duplicate count:", df.duplicated().sum())
# Out:
# Before duplicates: (45000, 52)
# After duplicates: (45000, 52)
# Duplicate count: 0

# %%
df["department_name"].unique()
# Out:
# <StringArray>
# ['Pediatrics', 'Orthopedics', 'Emergency', 'Internal Medicine', 'Surgery',
#  'ICU']
# Length: 6, dtype: str

# %%
df["department_name"] = (
    df["department_name"]
    .astype(str)
    .str.strip()
    .str.title()
)

# %%
df["department_name"].unique()
# Out:
# <StringArray>
# ['Pediatrics', 'Orthopedics', 'Emergency', 'Internal Medicine', 'Surgery',
#  'Icu']
# Length: 6, dtype: str

# %%
df["department_name"].unique()
# Out:
# <StringArray>
# ['Pediatrics', 'Orthopedics', 'Emergency', 'Internal Medicine', 'Surgery',
#  'Icu']
# Length: 6, dtype: str

# %%
cat_columns = [
    "admission_type",
    "admission_status",
    "gender",
    "blood_group",
    "city",
    "department_type",
    "ward_type",
    "bed_status",
    "disease_category"
]

for col in cat_columns:
    if col in df.columns:
        df[col] = (
            df[col]
            .astype(str)
            .str.strip()
            .str.title()
        )

# %%
date_columns = [
    "admission_date",
    "discharge_date",
    "date_of_birth"
]

for col in date_columns:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col])

# %%
print("Dataset Shape:", df.shape)

print("Missing Values:",
      df.isnull().sum().sum())

print("Duplicates:",
      df.duplicated().sum())
# Out:
# Dataset Shape: (45000, 52)
# Missing Values: 0
# Duplicates: 0

# %%
import pandas as pd

# Load raw data
df = pd.read_csv(r"D:\MedTrack_DV\data\processed\hospital_raw_data.csv")

# Drop unwanted columns
drop_cols = [
    "provider_type",
    "patient_insurance_id",
    "contact_details",
    "policy_start_date",
    "policy_end_date",
    "insurance_provider_id"
]

df.drop(columns=[c for c in drop_cols if c in df.columns], inplace=True)

print("Before saving:", df.shape)

# Save cleaned file
df.to_csv(r"D:\MedTrack_DV\data\cleaned\hospital_cleaned.csv", index=False)

# Read the file we just saved
check = pd.read_csv(r"D:\MedTrack_DV\data\cleaned\hospital_cleaned.csv")

print("After saving:", check.shape)
# Out:
# Before saving: (45000, 52)
# After saving: (45000, 52)
